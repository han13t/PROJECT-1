# %% [markdown]
# # Data analysis of the dataset of all inventories of red wine #

# %%
import pandas as pd
import seaborn as sn
from matplotlib import pyplot as plt
import numpy as np
from scipy import stats

# %%
data = pd.read_csv('data.csv')
data
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %% [markdown]
# # __Now we need to describe the dataset to identify and pre-process any null and duplicate values.__ #

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1600 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1600 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1598 non-null   float64
#  6   free sulfur dioxide   1600 non-null   float64
#  7   total sulfur dioxide  1600 non-null   float64
#  8   density               1600 non-null   float64
#  9   pH                    1600 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1600 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 162.7 KB

# %% [markdown]
# ##  An ordered way to identify null values is to:  ##

# %%
data_summary = data.describe()

null_counts = data.isnull().sum()

data_summary.loc['null_count'] = null_counts

data_summary = data_summary.transpose()

data_summary
# Out:
#                        count        mean         std      min       25%  \
# ID                    1601.0  801.000000  462.313206  1.00000  401.0000
# fixed acidity         1600.0    8.319875    1.740039  4.60000    7.1000
# volatile acidity      1601.0    0.527742    0.178981  0.12000    0.3900
# citric acid           1600.0    0.271175    0.194745  0.00000    0.0900
# residual sugar        1601.0    2.538445    1.409138  0.90000    1.9000
# chlorides             1598.0    0.087487    0.047076  0.01200    0.0700
# free sulfur dioxide   1600.0   15.886875   10.458487  1.00000    7.0000
# total sulfur dioxide  1600.0   46.520000   32.977723  6.00000   22.0000
# density               1600.0    0.996746    0.001887  0.99007    0.9956
# pH                    1600.0    3.311106    0.154338  2.74000    3.2100
# sulphates             1601.0    0.658220    0.169471  0.33000    0.5500
# alcohol               1601.0   10.423204    1.065495  8.40000    9.5000
# ...

# %% [markdown]
# __The isnull().sum() method is used to count the number of null values in each columns. We then add the null count information to the data_summary statistics using the loc[ ] method and we create a new row called the "null.count".Then finally we use the transpose() method to allow easy viewing so that the columns are the variables and the rows are the data_summary statistics.
# From the data summary we see the the columns that contain null values.__

# %% [markdown]
# ## In order to pre- process the dataset we need to rename some of the columns in the dataset.  To do so we do the following: ##

# %%
data = data.rename(columns={'fixed acidity':'fixed_acidity', 'volatile acidity':'volatile_acidity', 'citric acid':'citric_acid', 'residual sugar':'residual_sugar', 'free sulfur dioxide':'free_sulfur_dioxide', 'total sulfur dioxide':'total_sulfur_dioxide'})
data
# Out:
#         ID  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# ...

# %% [markdown]
# ## _We can choose to get rid of the null values for good and to do so we do the following:_ ##

# %%
x = data.dropna()
x
# Out:
#         ID  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density        pH  \
# ...

# %% [markdown]
# __The .dropna() introduced removes instances where null sets are found and leaves instances that have value. Therefore as seen above the number of rows decreases from 1601 to 1591 but we don't want to reduce the number of rows so we won't use the dropna method__.

# %% [markdown]
# ## Pre-Processing using the mean method ##

# %% [markdown]
# __A better way of replacing null values is by finding its mean,mode or median. We choose to use the mean method because it gives us the average value of the columns that have null values.__

# %%
data
# Out:
#         ID  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# ...

# %%
mean_fixed_acidity = data.fixed_acidity.mean()
mean_citric_acid = data.citric_acid.mean()
mean_chlorides = data.chlorides.mean()
mean_free_sulfur_dioxide = data.free_sulfur_dioxide.mean()
mean_total_sulfur_dioxide = data.total_sulfur_dioxide.mean()
mean_density = data.density.mean()
mean_pH = data.pH.mean()
mean_quality = data.quality.mean()

# %%
print(f'fixed_acidity: {mean_fixed_acidity}')
print(f'citric_acid: {mean_citric_acid}')
print(f'chlorides: {mean_chlorides}')
print(f'free_sulfur_dioxide: {mean_free_sulfur_dioxide}')
print(f'total_sulfur_dioxide: {mean_total_sulfur_dioxide}')
print(f'density: {mean_density}')
print(f'pH: {mean_pH}')
print(f'quality: {mean_quality}')
# Out:
# fixed_acidity: 8.319875000000001
# citric_acid: 0.271175
# chlorides: 0.0874874843554443
# free_sulfur_dioxide: 15.886875
# total_sulfur_dioxide: 46.52
# density: 0.9967456437500002
# pH: 3.3111062500000004
# quality: 5.63625

# %%
data['fixed_acidity'] = data['fixed_acidity'].fillna(mean_fixed_acidity)
data['citric_acid'] = data['citric_acid'].fillna(mean_citric_acid)
data['chlorides'] = data['chlorides'].fillna(mean_chlorides)
data['free_sulfur_dioxide'] = data['free_sulfur_dioxide'].fillna(mean_free_sulfur_dioxide)
data['total_sulfur_dioxide'] = data['total_sulfur_dioxide'].fillna(mean_total_sulfur_dioxide)
data['density'] = data['density'].fillna(mean_density)
data['pH'] = data['pH'].fillna(mean_pH)
data['quality'] = data['quality'].fillna(mean_quality)

# %%
data
# Out:
#         ID  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density        pH  \
# ...

# %% [markdown]
# ### Let's check our dataset to see if there are any null values again ###

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed_acidity         1601 non-null   float64
#  2   volatile_acidity      1601 non-null   float64
#  3   citric_acid           1601 non-null   float64
#  4   residual_sugar        1601 non-null   float64
#  5   chlorides             1601 non-null   float64
#  6   free_sulfur_dioxide   1601 non-null   float64
#  7   total_sulfur_dioxide  1601 non-null   float64
#  8   density               1601 non-null   float64
#  9   pH                    1601 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1601 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 162.7 KB

# %%
data.describe()
# Out:
#                 ID  fixed_acidity  volatile_acidity  citric_acid  \
# count  1601.000000    1601.000000       1601.000000  1601.000000
# mean    801.000000       8.319875          0.527742     0.271175
# std     462.313206       1.739495          0.178981     0.194684
# min       1.000000       4.600000          0.120000     0.000000
# 25%     401.000000       7.100000          0.390000     0.090000
# 50%     801.000000       7.900000          0.520000     0.260000
# 75%    1201.000000       9.200000          0.640000     0.420000
# max    1601.000000      15.900000          1.580000     1.000000
#
#        residual_sugar    chlorides  free_sulfur_dioxide  total_sulfur_dioxide  \
# count     1601.000000  1601.000000          1601.000000           1601.000000
# mean         2.538445     0.087487            15.886875             46.520000
# std          1.409138     0.047032            10.455218             32.967416
# ...

# %% [markdown]
# #### We see from the above that there are no more null values in our dataset. ###

# %% [markdown]
# ## Pre - Processing data duplicates ##

# %%
num_duplicates = data.duplicated().sum()
print(f' The data contains {num_duplicates} duplicated rows.')
# Out:
#  The data contains 0 duplicated rows.

# %% [markdown]
# #### The duplicated().sum() method counts the number of true values in the data. ###

# %% [markdown]
# ## Another intresting data analysis we can do on the data is counting the number of unique values ##

# %%
print(f'alcohol: {data.alcohol.nunique()}')
print(f'ID: {data.ID.nunique()}')
print(f'pH: {data.pH.nunique()}')
print(f'citric_acid: {data.citric_acid.nunique()}')
print(f'quality: {data.quality.nunique()}')
print(f'volatile_acidity: {data.volatile_acidity.nunique()}')
print(f'fixed_acidity: {data.fixed_acidity.nunique()}')
print(f'residual_sugar: {data.residual_sugar.nunique()}')
print(f'chlorides: {data.chlorides.nunique()}')
print(f'free_sulfur_dioxide: {data.free_sulfur_dioxide.nunique()}')
print(f'total_sulfur_dioxide: {data.total_sulfur_dioxide.nunique()}')
print(f'density: {data.density.nunique()}')
print(f'sulphates: {data.sulphates.nunique()}')
# Out:
# alcohol: 65
# ID: 1601
# pH: 90
# citric_acid: 81
# quality: 7
# volatile_acidity: 143
# fixed_acidity: 97
# residual_sugar: 91
# chlorides: 154
# free_sulfur_dioxide: 61
# total_sulfur_dioxide: 145
# density: 436
# sulphates: 96

# %% [markdown]
# # Statistical inferences of each of the columns in the dataset

# %%
q =np.array([8.319875,0.271175, 0.08748748435, 15.886875, 46.52, 0.99674564375, 3.31110625, 5.63625 ])
myLabels =['fixed_acidity', 'citric_acid', 'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide','density', 'pH', 'quality']
explode= (0, 0, 0.3, 0, 0, 0, 0, 0)

plt.figure(figsize=(7,10))
plt.title('MEAN OF SPECIFIC COLUMNS', fontsize=9, fontweight='bold')
# plt.style.use('ggplot')
plt.pie(q,labels=myLabels,explode=explode,startangle=0,autopct='%.1f%%',colors=('blue','lightyellow','gold','green','red','grey','orange','lightgreen'))
plt.legend(loc='lower left', fontsize=6)
plt.show()

# %% [markdown]
# ### We can see from the pie chart above that total_sulfur_dioxide has a relatively large percentage compared to the others and also the percentage of chlorides and citric_acid respectively are relatively small telling us that the amount of quantity of chlorides and citric acid are very low

# %%
plt.figure(figsize=(10, 5))
viz = sn.barplot(x=data['quality'], y=data['alcohol'])
viz.set_xticklabels(viz.get_xticklabels(), rotation=25)
plt.title('QUALITY AGAINST ALCOHOL')
plt.show()

# %%
q =np.array([8.319875, 0.9967456437])
myLabels =['fixed_acidity', 'density']
explode= (0, 0.3)

plt.figure(figsize=(7,10))
plt.title('MEAN OF F.S AGAINST DENSITY', fontsize=9, fontweight='bold')
# plt.style.use('ggplot')
plt.pie(q,labels=myLabels,explode=explode,startangle=0,autopct='%.1f%%',colors=('blue','gold'))
plt.legend(loc='lower left', fontsize=6)
plt.show()

# %% [markdown]
# ### We can identify from the pie chart that fixed_acidity is relatively high as compared to density

# %%
q =np.array([46.52, 3.31110625])
myLabels =['total_sulfur_dioxide', 'pH']
explode= (0,  0.3)

plt.figure(figsize=(7,10))
plt.title('MEAN OF T.S VERSUS pH', fontsize=9, fontweight='bold')
# plt.style.use('ggplot')
plt.pie(q,labels=myLabels,explode=explode,startangle=0,autopct='%.1f%%',colors=('red','green'))
plt.legend(loc='lower left', fontsize=6)
plt.show()

# %% [markdown]
# ### From the pie chart we can identify that the total_sulfur_dioxide is relatively larger than the pH. The commented line allows us to customise the plot of our chart that is to set the color of our chart to our own liking.

# %% [markdown]
# #  __Finally we make a correlation of our dataset.__

# %%
data.corr()
# This allows us to show a data correlation among columns
# Out:
#                             ID  fixed_acidity  volatile_acidity  citric_acid  \
# ID                    1.000000      -0.267899         -0.009544    -0.153294
# fixed_acidity        -0.267899       1.000000         -0.255557     0.670856
# volatile_acidity     -0.009544      -0.255557          1.000000    -0.552909
# citric_acid          -0.153294       0.670856         -0.552909     1.000000
# residual_sugar       -0.031589       0.114595          0.001877     0.143517
# chlorides            -0.119131       0.093472          0.060748     0.203981
# free_sulfur_dioxide   0.091145      -0.152932         -0.010591    -0.061252
# total_sulfur_dioxide -0.113809      -0.113325          0.076247     0.036014
# density              -0.368725       0.667693          0.022753     0.364104
# pH                    0.135082      -0.682452          0.235182    -0.542637
# sulphates            -0.124243       0.182291         -0.261364     0.312839
# ...

# %% [markdown]
# ### from the above dataset we can make the following conclusions:
#
# ### 1.)Every column matching to it's own corresponding row has a value of 1.
#
# ### 2.) Volatile acidity column and the fixed acidity row produces a positive high value.
#
# ### 3.) ID column and volatile acidity row correlates to a realtively low negative value.
#
# ### 4.)  Chlorides column and the free sulfur dioxide row correlates to  a reatively low positive value.
